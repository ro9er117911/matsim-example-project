# %% [markdown]
# # Inspect MATSim Trajectory Parquet Format
#
# This notebook inspects the schema and content of the generated `trip_animation.parquet` file.

# %%
import pandas as pd
import os

parquet_path = '../output_vis/trip_animation.parquet'
if not os.path.exists(parquet_path):
    # Try absolute path if relative fails
    parquet_path = '/Users/ro9air/matsim-example-project/5000_disatar/06_taipei_test/output_vis/trip_animation.parquet'

print(f"Loading: {parquet_path}")
df = pd.read_parquet(parquet_path)

print("\n--- Dataframe Info ---")
print(df.info())

print("\n--- Columns ---")
print(df.columns.tolist())

print("\n--- Sample Data (First 5 Rows) ---")
pd.set_option('display.max_colwidth', 100)
display(df.head())

print("\n--- Path Length Check ---")
print(f"First path has {len(df['paths'].iloc[0])} coordinates (x,y flat list)")
print(f"First trajectory has {len(df['timestamps'].iloc[0])} timestamps")
# Out:
# Loading: ../output_vis/trip_animation.parquet
#
# --- Dataframe Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   paths       354 non-null    object
#  1   timestamps  354 non-null    object
#  2   modes       354 non-null    object
# dtypes: object(3)
# memory usage: 8.4+ KB
# None
#
# --- Columns ---
# ['paths', 'timestamps', 'modes']
#
# --- Sample Data (First 5 Rows) ---
#                                                                                                  paths  \
# 0  [121.579883946842, 24.985537631559332, 121.66760600172456, 25.081480822398813, 121.6676060017245...
# 1  [121.5595272784996, 25.033123368837753, 121.66760600172456, 25.081480822398813, 121.667606001724...
# 2  [121.52187742472857, 25.09447865222557, 121.66760600172456, 25.081480822398813, 121.667606001724...
# ...
